# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
plt.figure(figsize = (15,6))
sns.distplot(df['price'], kde=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10988\1526775796.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'], kde=True)
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.countplot(x = df['bedrooms'])
# Out:
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
df.corr(numeric_only=True)['price'].sort_values(ascending = False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = 'price', y = 'sqft_living', data = df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize = (10,6))
sns.boxplot(x = 'bedrooms', y = 'price', data= df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.scatterplot(x = 'price', y = 'long', data = df)
# Out:
# <Axes: xlabel='price', ylabel='long'>

# %%
sns.scatterplot(x = 'price', y = 'lat', data = df)
# Out:
# <Axes: xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x = 'long', y = 'lat', data = df, hue = 'price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
df.sort_values('price', ascending = False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
df_99 = df.sort_values('price', ascending = False).iloc[216:]

# %%
df_99['price'].max()
# Out:
# 1970000.0

# %%
sns.displot(df_99['price'], kde = True, height = 5, aspect = 2)

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(x = 'long', y = 'lat', data = df_99, hue = 'price', 
                edgecolor = None, alpha = 0.5, palette = 'RdYlGn')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x = 'waterfront', y = 'price', data = df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
df = df.drop('id', axis = 1)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize = (10,5))
sns.boxplot(x = 'month', y = 'price', data = df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10988\3834763391.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('month').mean()['price'].plot()
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10988\366114082.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('year').mean()['price'].plot()
# <Axes: xlabel='year'>

# %%
df = df.drop('date', axis = 1)
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis = 1)

# %%
X = df.drop('price', axis = 1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_test.max()
# Out:
# 3.2

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss = 'mse')

# %%
model.fit(x = X_train, y = y_train, 
          validation_data = (X_test, y_test),
         batch_size = 128, epochs = 400
         )
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 4ms/step - loss: 430236532736.0000 - val_loss: 418900770816.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 428997574656.0000 - val_loss: 414673240064.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 412059336704.0000 - val_loss: 375854891008.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 328634761216.0000 - val_loss: 240483811328.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 3ms/step - loss: 168699297792.0000 - val_loss: 105812672512.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 3ms/step - loss: 100717101056.0000 - val_loss: 94520639488.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 3ms/step - loss: 96863182848.0000 - val_loss: 92944130048.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = pd.DataFrame(model.predict(X_test), columns = ['Predicted Price'])
# Out:
# 203/203 [==============================] - 1s 2ms/step

# %%
predictions['Y Test'] = y_test
predictions
# Out:
#       Predicted Price     Y Test
# 0        433280.56250   319000.0
# 1        592745.37500   464625.0
# 2        589187.12500   489950.0
# 3        395425.81250   395000.0
# 4        474602.62500   458000.0
# ...               ...        ...
# 6475     659870.43750   585000.0
# 6476     219516.90625   132825.0
# 6477     411255.75000   422500.0
# 6478     572942.56250   435000.0
# 6479     681751.31250  1230000.0
#
# [6480 rows x 2 columns]

# %%
sns.scatterplot(x = y_test, y = predictions['Predicted Price'])
# Out:
# <Axes: ylabel='Predicted Price'>

# %%
mean_squared_error(y_test, predictions['Predicted Price'])**0.5
# Out:
# 162921.8027961248

# %%
mean_absolute_error(y_test, predictions['Predicted Price'])
# Out:
# 100443.62223910108

# %%
explained_variance_score(y_test, predictions['Predicted Price'])
# Out:
# 0.7998773116233693

# %%
single_house = df.drop('price', axis = 1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([[281774.47]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
pd.DataFrame(mean_absolute_error(y_test, predictions['Predicted Price'])/df['price']).mean()
# Out:
# price    0.246399
# dtype: float64
